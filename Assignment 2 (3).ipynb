# %% [markdown]
# ## 2nd Assignment

# %%
 #!/usr/bin/python
import getpass
import string
import os
need 
# you have to take account number: 
# take a password fromuser 
# if username in database:
#    if password in database:
#         login sucess
    
    
    database = {
        eddygrant000:{
            'name': 'Sachin',
            'age': 22,
            'email': 'eddygrant000@gmail.com',
            'password': 'red@123',
            'amount': 20000,
        },
        sachin000:{
            'name': 'Tanuj',
            'age': 25,
            'email': 'tanuj@gmail.com',
            'password': 'tanu123',
             'amount': 10000
        }
    }
       
        
    Display = input('SELECT FROM FOLLOWING OPTIONS: \n1.Login___(1) \n2.Signup___(2) \n3.Exit___\Enter your choice:').lower() 
    Valid _Display = ['1','2','3']
    Display = Display.lower()
if Display == 1
        open  Login ()
elseif Display == 2
        open Signup ()
else: Display == 3
        Exit:
        def Login():   
            status1 = input('Are you olduser? y/n? press 3 to Exit page'')
            if status == "y"?
            open Login ()
            if status == "n"?
            open Signup ()   
        def Signup():   
            status = input('Are you newuser? y/n? press 3 to Exit page')
            if status == "y"?
            open Signup ()
            if status == "n"?
            open Login ()
        def displaymenu():
            status = input('Are you sign user? y/n? press 3 to Exit page')
            if status == "y"?
            olduser ()
            if status == "n"?
            newuser ()
        def newuser():
            createlogin = input('create login name:') 
            if createlogin in database.keys()
                 print("\nlogin name already exist!\n")
            else:
                createpasswd = input('create new passwd:')
                users[createlogin] = createpasswd
                print ("\nuser created\n")
        def olduser():   
            username = input("Enter login name: ")
            passwd = input("Enter password: ")

            if login in database.keys() and users[createlogin] = createpasswd
                if passwd == database[username]['password']:
                print(f"Login Success\nWelcome {database[username]['name']}")
            else:
                print("\nuser doesn't exist or wrong passwd!\n")

while status = Exit
        
        response = input('SELECT FROM FOLLOWING OPTIONS: \n1.Balance Check___(1) \n2.Deposite Balance___(2) \withdrawl___(3) \n4.Exit___(4) \nEnter you Choices: ').lower()
        
        valid_responses = ['1', '2', '3', '4']
        response = response.lower()
        if response == '1':
            print(str.capitalize(users[n]), 'YOU HAVE ', amounts[n],'BOB ON YOUR ACCOUNT.')
        elif response == '2':
            cash_out = int(input('ENTER AMOUNT YOU WOULD LIKE TO WITHDRAW: '))
            
            if cash_out%10 != 0:
                print('AMOUNT YOU WANT TO WITHDRAW ')
            elif cash_out > amounts[n]:
                print('YOU HAVE INSUFFICIENT BALANCE')
            else:
                amounts[n] = amounts[n] - cash_out
            print('YOUR NEW BALANCE IS: ', amounts[n], 'BOB')
            
        elif response == '3':
            cash_in = int(input('ENTER AMOUNT YOU WOULD LIKE TO DEPOSIT: '))
            
            if cash_in%10 != 0:
                print('AMOUNT YOU WANT TO DEPOSIT ')
            else:
                amounts[n] = amounts[n] + cash_in
                print('YOUR NEW BALANCE IS: ', amounts[n], 'BOB')
        elif response == 'q':
                exit()
        else:
            print('RESPONSE NOT VALID')

# %%
r = lambda q: q * 2
s = lambda q: q * 3
x = 2
x = r(x) 
x = s(x) 
x = r(x) 
print(x)
# Out:
# 24
